# %%
import h5py
import numpy as np
import matplotlib as plt

# %%
from openTSNE import TSNE
from openTSNE.callbacks import ErrorLogger

# %%
import os


home = os.getenv('HOME')
scratch = os.getenv('SCRATCH')

#preprocessed_path = home + '/projects/rrg-kyi/group_writable/spectra/preprocessed/'
filepath1 = scratch + '/tsne_data_350'
filepath2 = scratch + '/tsne_data_350_700'
filepath3 = scratch + '/tsne_data_700_1050'
filepath4 = scratch + '/tsne_data_1050_1400'
filepath5 = scratch + '/tsne_data_1400_1750'
filepath6 = scratch + '/tsne_data_1750_2100'
filepath7 = scratch + '/tsne_data_2100_2480'

# %%
flux_a_fin = []
flux_p_fin = []
flux_i_fin = []
flux_u_fin = []

flux_a_aug_fin = []
flux_p_aug_fin = []
flux_i_aug_fin = []


f1 = h5py.File(filepath1, 'r')
print(list(f1))
flux_a = f1['ambre']
flux_p = f1['phoenix']
flux_i = f1['intrigoss']
flux_u = f1['uves']

flux_a_aug = f1['ambre_aug']
flux_p_aug = f1['phoenix_aug']
flux_i_aug = f1['intrigoss_aug']
#flux_u_aug = f1['uves_aug']
# Out:
# ['ambre', 'ambre_aug', 'intrigoss', 'intrigoss_aug', 'phoenix', 'phoenix_aug', 'uves']

# %%
for i in flux_a:
    flux_a_fin.append(i)
for i in flux_p:
    flux_p_fin.append(i)
for i in flux_i:
    flux_i_fin.append(i)
for i in flux_u:
    flux_u_fin.append(i)
    
for i in flux_a_aug:
    flux_a_aug_fin.append(i)
for i in flux_i_aug:
    flux_i_aug_fin.append(i)
for i in flux_p_aug:
    flux_p_aug_fin.append(i)

# %%
f2 = h5py.File(filepath2, 'r')
print(list(f2))
# Out:
# ['ambre', 'ambre_aug', 'intrigoss', 'intrigoss_aug', 'phoenix', 'phoenix_aug', 'uves']

# %%
dset_a = f2['ambre']
dset_p = f2['phoenix']
dset_i = f2['intrigoss']
#dset_u = f2['uves']

dset_a_aug = f2['ambre_aug']
dset_p_aug = f2['phoenix_aug']
dset_i_aug = f2['intrigoss_aug']
#dset_u_aug = f2['uves_aug']

for i in dset_a:
    flux_a_fin.append(i)
for i in dset_p:
    flux_p_fin.append(i)
for i in dset_i:
    flux_i_fin.append(i)

    
for i in dset_a_aug:
    flux_a_aug_fin.append(i)
for i in dset_i_aug:
    flux_i_aug_fin.append(i)

for i in dset_p_aug:
    flux_p_aug_fin.append(i)

# %%
f3 = h5py.File(filepath3, 'r')
print(list(f3))
# Out:
# ['ambre', 'ambre_aug', 'intrigoss', 'intrigoss_aug', 'phoenix', 'phoenix_aug', 'uves']

# %%
dset_a = f3['ambre']
dset_p = f3['phoenix']
dset_i = f3['intrigoss']
#dset_u = f2['uves']

dset_a_aug = f3['ambre_aug']
dset_p_aug = f3['phoenix_aug']
dset_i_aug = f3['intrigoss_aug']
#dset_u_aug = f2['uves_aug']

for i in dset_a:
    flux_a_fin.append(i)
for i in dset_p:
    flux_p_fin.append(i)
for i in dset_i:
    flux_i_fin.append(i)

    
for i in dset_a_aug:
    flux_a_aug_fin.append(i)
for i in dset_i_aug:
    flux_i_aug_fin.append(i)

for i in dset_p_aug:
    flux_p_aug_fin.append(i)

# %%
f4 = h5py.File(filepath4, 'r')
print(list(f4))
# Out:
# ['ambre', 'ambre_aug', 'intrigoss', 'intrigoss_aug', 'phoenix', 'phoenix_aug', 'uves']

# %%
dset_a = f4['ambre']
dset_p = f4['phoenix']
dset_i = f4['intrigoss']
#dset_u = f2['uves']

dset_a_aug = f4['ambre_aug']
dset_p_aug = f4['phoenix_aug']
dset_i_aug = f4['intrigoss_aug']
#dset_u_aug = f2['uves_aug']

for i in dset_a:
    flux_a_fin.append(i)
for i in dset_p:
    flux_p_fin.append(i)
for i in dset_i:
    flux_i_fin.append(i)

    
for i in dset_a_aug:
    flux_a_aug_fin.append(i)
for i in dset_i_aug:
    flux_i_aug_fin.append(i)

for i in dset_p_aug:
    flux_p_aug_fin.append(i)

# %%
f5 = h5py.File(filepath5, 'r')
print(list(f5))
# Out:
# ['ambre', 'ambre_aug', 'intrigoss', 'intrigoss_aug', 'phoenix', 'phoenix_aug', 'uves']

# %%
dset_a = f5['ambre']
dset_p = f5['phoenix']
dset_i = f5['intrigoss']
#dset_u = f2['uves']

dset_a_aug = f5['ambre_aug']
dset_p_aug = f5['phoenix_aug']
dset_i_aug = f5['intrigoss_aug']
#dset_u_aug = f2['uves_aug']

for i in dset_a:
    flux_a_fin.append(i)
for i in dset_p:
    flux_p_fin.append(i)
for i in dset_i:
    flux_i_fin.append(i)

    
for i in dset_a_aug:
    flux_a_aug_fin.append(i)
for i in dset_i_aug:
    flux_i_aug_fin.append(i)

for i in dset_p_aug:
    flux_p_aug_fin.append(i)

# %%
f6 = h5py.File(filepath6, 'r')
print(list(f6))
# Out:
# ['ambre', 'ambre_aug', 'intrigoss', 'intrigoss_aug', 'phoenix', 'phoenix_aug', 'uves']

# %%
dset_a = f6['ambre']
dset_p = f6['phoenix']
dset_i = f6['intrigoss']
#dset_u = f2['uves']

dset_a_aug = f6['ambre_aug']
dset_p_aug = f6['phoenix_aug']
dset_i_aug = f6['intrigoss_aug']
#dset_u_aug = f2['uves_aug']

for i in dset_a:
    flux_a_fin.append(i)
for i in dset_p:
    flux_p_fin.append(i)
for i in dset_i:
    flux_i_fin.append(i)

    
for i in dset_a_aug:
    flux_a_aug_fin.append(i)
for i in dset_i_aug:
    flux_i_aug_fin.append(i)

for i in dset_p_aug:
    flux_p_aug_fin.append(i)

# %%
f7 = h5py.File(filepath7, 'r')
print(list(f7))
# Out:
# ['ambre', 'ambre_aug', 'intrigoss', 'intrigoss_aug', 'phoenix', 'phoenix_aug', 'uves']

# %%
dset_a = f7['ambre']
dset_p = f7['phoenix']
dset_i = f7['intrigoss']
#dset_u = f2['uves']

dset_a_aug = f7['ambre_aug']
dset_p_aug = f7['phoenix_aug']
dset_i_aug = f7['intrigoss_aug']
#dset_u_aug = f2['uves_aug']

for i in dset_a:
    flux_a_fin.append(i)
for i in dset_p:
    flux_p_fin.append(i)
for i in dset_i:
    flux_i_fin.append(i)

    
for i in dset_a_aug:
    flux_a_aug_fin.append(i)
for i in dset_i_aug:
    flux_i_aug_fin.append(i)

for i in dset_p_aug:
    flux_p_aug_fin.append(i)

# %%
flux_a_aug_fin = np.asarray(flux_a_aug_fin)
flux_p_aug_fin = np.asarray(flux_p_aug_fin)
flux_i_aug_fin = np.asarray(flux_i_aug_fin)
#flux_u_aug = np.asarray(flux_u_aug)

flux_a_fin = np.asarray(flux_a_fin)
flux_u_fin = np.asarray(flux_u_fin)
flux_p_fin = np.asarray(flux_p_fin)
flux_i_fin = np.asarray(flux_i_fin)


print(flux_a_aug_fin.shape)
print(flux_p_aug_fin.shape)
print(flux_i_aug_fin.shape)


print(flux_a_fin.shape)
print(flux_p_fin.shape)
print(flux_i_fin.shape)
print(flux_u_fin.shape)
# Out:
# (1664, 39436)
# (833, 39436)
# (2480, 39436)
# (1664, 39436)
# (833, 39436)
# (2480, 39436)
# (2480, 39436)

# %%
grid_data = []
for i in flux_i_fin:
    grid_data.append(i)
for j in flux_p_fin:
    grid_data.append(j)
for k in flux_a_fin:
    grid_data.append(k)
for l in flux_u_fin:
    grid_data.append(l)

grid_data = np.asarray(grid_data)
print(grid_data.shape)
# Out:
# (7457, 39436)

# %%
grid_data_aug = []
for i in flux_i_aug_fin:
    grid_data_aug.append(i)
for j in flux_p_aug_fin:
    grid_data_aug.append(j)
for k in flux_a_aug_fin:
    grid_data_aug.append(k)
for l in flux_u_fin:
    grid_data_aug.append(l)


grid_data_aug = np.asarray(grid_data_aug)
print(grid_data_aug.shape)
# Out:
# (7457, 39436)

# %%
tsne = TSNE(
    perplexity=30,
    metric="euclidean",
    callbacks=ErrorLogger(),
    n_jobs=8,
    random_state=42,
)

# %%
# %time embedding_train = tsne.fit(grid_data)
# Out:
# Iteration   50, KL divergence  3.4290, 50 iterations in 0.4785 sec
# Iteration  100, KL divergence  2.9362, 50 iterations in 0.4817 sec
# Iteration  150, KL divergence  2.7456, 50 iterations in 0.4831 sec
# Iteration  200, KL divergence  2.6097, 50 iterations in 0.4826 sec
# Iteration  250, KL divergence  2.5360, 50 iterations in 0.4788 sec
# Iteration   50, KL divergence  1.5516, 50 iterations in 0.4633 sec
# Iteration  100, KL divergence  1.1618, 50 iterations in 0.4708 sec
# Iteration  150, KL divergence  0.9957, 50 iterations in 1.1111 sec
# Iteration  200, KL divergence  0.9230, 50 iterations in 1.6318 sec
# Iteration  250, KL divergence  0.8903, 50 iterations in 2.0426 sec
# Iteration  300, KL divergence  0.8643, 50 iterations in 2.6977 sec
# Iteration  350, KL divergence  0.8451, 50 iterations in 3.3319 sec
# Iteration  400, KL divergence  0.8272, 50 iterations in 3.9793 sec
# Iteration  450, KL divergence  0.8111, 50 iterations in 3.8910 sec
# ...

# %%
# %time embedding_train_aug = tsne.fit(grid_data_aug)
# Out:
# Iteration   50, KL divergence  3.4686, 50 iterations in 0.4750 sec
# Iteration  100, KL divergence  3.0318, 50 iterations in 1.0667 sec
# Iteration  150, KL divergence  2.7694, 50 iterations in 2.5349 sec
# Iteration  200, KL divergence  2.6773, 50 iterations in 0.7889 sec
# Iteration  250, KL divergence  2.5289, 50 iterations in 2.5342 sec
# Iteration   50, KL divergence  1.5558, 50 iterations in 0.6368 sec
# Iteration  100, KL divergence  1.0754, 50 iterations in 0.4763 sec
# Iteration  150, KL divergence  0.9108, 50 iterations in 1.0364 sec
# Iteration  200, KL divergence  0.8408, 50 iterations in 1.5209 sec
# Iteration  250, KL divergence  0.8083, 50 iterations in 1.9349 sec
# Iteration  300, KL divergence  0.7813, 50 iterations in 2.5506 sec
# Iteration  350, KL divergence  0.7636, 50 iterations in 3.5017 sec
# Iteration  400, KL divergence  0.7451, 50 iterations in 3.6216 sec
# Iteration  450, KL divergence  0.7351, 50 iterations in 3.9893 sec
# ...

# %%
import matplotlib.pyplot as plt

fig1, ax = plt.subplots(figsize = (10,10))

colors = ['r', 'g','k','c']

intrigoss = ax.scatter(embedding_train[:len(flux_i_fin), 0], embedding_train[:len(flux_i_fin), 1],color = colors[0] ,s = 15,alpha = 0.5)
phoenix = ax.scatter(embedding_train[len(flux_i_fin):len(flux_i_fin)+len(flux_p_fin), 0], embedding_train[len(flux_i_fin):len(flux_i_fin)+len(flux_p_fin), 1],color = colors[1] ,s = 15,alpha = 0.5)
ambre = ax.scatter(embedding_train[len(flux_i_fin)+len(flux_p_fin):, 0], embedding_train[len(flux_i_fin)+len(flux_p_fin):, 1],color = colors[2],s = 15,alpha = 0.5)
uves = ax.scatter(embedding_train[len(flux_i_fin)+len(flux_p_fin)+len(flux_a_fin):, 0], embedding_train[len(flux_i_fin)+len(flux_p_fin)+len(flux_a_fin):, 1],color = colors[3],s = 15,alpha = 0.5)
#uves = ax.scatter(embedding_train1[:, 0], embedding_train1[:, 1],color = colors[3],s = 30)

plt.gca().set_aspect('equal', 'datalim')
#plt.plot(x, y1, '-b', label='sine')
#plt.plot(x, y2, '-r', label='cosine')
plt.legend((intrigoss,phoenix,ambre,uves),
           ('INTRIGOSS', 'PHOENIX', 'AMBRE','UVES'),
           scatterpoints=1,
           loc='upper left',
           ncol=1,
           fontsize=10)

#plt.title('t-SNE of the 3 grids [ T>5000 and logg>3 and -1<Fe<0.]', fontsize=15);
plt.savefig('noiseless_grids.png')

# %%
fig, ax1 = plt.subplots(figsize = (10,10))

colors = ['r', 'g','k','c']

intrigoss = ax1.scatter(embedding_train_aug[:len(flux_i_fin), 0], embedding_train_aug[:len(flux_i_fin), 1],color = colors[0] ,s = 15,alpha = 0.5)
phoenix = ax1.scatter(embedding_train_aug[len(flux_i_fin):len(flux_i_fin)+len(flux_p_fin), 0], embedding_train_aug[len(flux_i_fin):len(flux_i_fin)+len(flux_p_fin), 1],color = colors[1] ,s = 15,alpha = 0.5)
ambre = ax1.scatter(embedding_train_aug[len(flux_i_fin)+len(flux_p_fin):, 0], embedding_train_aug[len(flux_i_fin)+len(flux_p_fin):, 1],color = colors[2],s = 15,alpha = 0.5)
uves = ax1.scatter(embedding_train_aug[len(flux_i_fin)+len(flux_p_fin)+len(flux_a_fin):, 0], embedding_train_aug[len(flux_i_fin)+len(flux_p_fin)+len(flux_a_fin):, 1],color = colors[3],s = 15,alpha = 0.5)
#uves = ax.scatter(embedding_train1[:, 0], embedding_train1[:, 1],color = colors[3],s = 30)

plt.gca().set_aspect('equal', 'datalim')
#plt.plot(x, y1, '-b', label='sine')
#plt.plot(x, y2, '-r', label='cosine')
plt.legend((intrigoss,phoenix,ambre,uves),
           ('INTRIGOSS', 'PHOENIX', 'AMBRE','UVES'),
           scatterpoints=1,
           loc='upper left',
           ncol=1,
           fontsize=10)

#plt.title('t-SNE of the 3 grids [ T>5000 and logg>3 and -1<Fe<0.]', fontsize=15);
plt.savefig('noisy_grids.png')
